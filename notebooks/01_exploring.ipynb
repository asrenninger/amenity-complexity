# %% [markdown]
# # Amenity Complexity Exploratory Analysis
#
# This notebook demonstrates the workflow for computing amenity complexity using the `amenity_complexity` package.

# %%
import pandas as pd
import geopandas as gpd
import contextily as ctx

import matplotlib.pyplot as plt

from amenity_complexity.io import pois_from_foursquare, pois_from_overture, buildings_from_overture, building_parts_from_overture, clean_overture_buildings
from amenity_complexity.poi import parse_geometry, parse_categories, relevel_categories
from amenity_complexity.geo import load_fuas, bbox_from_fua, load_countries, bbox_from_country, pois_to_h3, aggregate_by_h3, h3_to_polygon
from amenity_complexity.core import compute_complexity

# %% [markdown]
# ## 1. Load Functional Urban Areas (FUAs)

# %%
# Load the FUA dataset (unzipped in data/)
fua_path = '../data/GHS_FUA_UCDB2015_GLOBE_R2019A_54009_1K_V1_0.gpkg'
fuas = load_fuas(fua_path)
print(f"Loaded {len(fuas)} FUAs.")
fuas.head()
# Out:
# Loaded 9031 FUAs.
#    eFUA_ID  UC_num UC_IDs   eFUA_name  Commuting Cntry_ISO   Cntry_name  \
# 0      1.0     1.0   5959       Herat        1.0       AFG  Afghanistan
# 1    192.0     1.0   5964     Guzarah        1.0       AFG  Afghanistan
# 2    354.0     1.0   5968    Shindand        0.0       AFG  Afghanistan
# 3    505.0     1.0   5970  Qala i Naw        0.0       AFG  Afghanistan
# 4    648.0     1.0   5973       Farah        1.0       AFG  Afghanistan
#
#    FUA_area  UC_area     FUA_p_2015      UC_p_2015    Com_p_2015  \
# 0     139.0     60.0  888811.175807  844574.564331  44236.611476
# 1      32.0     16.0  169489.573231  160204.260864   9285.312366
# 2      12.0     12.0  147553.403870  147553.403870      0.000000
# 3       3.0      3.0   79809.722656   79809.722656      0.000000
# 4      32.0     16.0  131508.797060  122843.460327   8665.336733
#
#                                             geometry
# 0  MULTIPOLYGON (((62.15405 34.40562, 62.17653 34...
# 1  MULTIPOLYGON (((62.22457 34.26645, 62.2358 34....
# 2  MULTIPOLYGON (((62.15458 33.32066, 62.16573 33...
# 3  MULTIPOLYGON (((63.13511 34.98061, 63.11253 34...
# 4  MULTIPOLYGON (((62.12915 32.39598, 62.14023 32...

# %% [markdown]
# ## 2. Select a Region (e.g., Budapest)
# We filter for a specific FUA. You can search by name if available, or ID.

# %%
# Example: Search for Budapest
# Note: Column names depend on the dataset. Usually 'eFUA_name' or similar.
target_city = 'London'
city_fua = fuas[fuas['eFUA_name'] == target_city]

if city_fua.empty:
    print(f"{target_city} not found. Showing first 5 names:")
    print(fuas['eFUA_name'].head())
else:
    fua_id = city_fua.iloc[0]['eFUA_ID']
    print(f"Found {target_city} with ID: {fua_id}")
    bbox = bbox_from_fua(fuas, 'eFUA_ID', fua_id)
    print(f"BBox: {bbox}")
# Out:
# Found Vienna with ID: 790.0
# BBox: (15.828431709164791, 47.78154121350172, 16.908136838053615, 48.55916103849195)

# %% [markdown]
# ## 3. Load POIs
# We fetch POIs from Foursquare (via DuckDB) within the bounding box.

# %%
pois_fsq = pois_from_foursquare(bbox=bbox, trim_cols=True)
print(f"Loaded {len(pois_fsq)} POIs.")
pois_fsq.head()
# Out:
# Loaded 196316 POIs.
#                          id                       name  \
# 0  5365c2e3498e4ed27d2fb162                    Zicksee
# 1  4c1a3d7bb9f876b0534c7846                    Zicksee
# 2  c7565b134316415abf688d96         Mag. Alois Tschida
# 3  502a3d6ee4b06703002e3c71  Nationalpark Info Illmitz
# 4  4e6a5143227162c38e60c199        Blamuka Probenlokal
#
#              top_category           sub_category  longitude   latitude  \
# 0  Landmarks and Outdoors              Surf Spot  16.899481  47.782440
# 1  Landmarks and Outdoors                   Lake  16.900012  47.783301
# 2     Dining and Drinking             Restaurant  16.785141  47.782681
# 3  Arts and Entertainment         Amusement Park  16.791806  47.795917
# 4  Arts and Entertainment  Performing Arts Venue  16.312642  47.785041
#
#   operating_status
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None

# %%
pois_omf = pois_from_overture(bbox=bbox, trim_cols=True)
print(f"Loaded {len(pois_omf)} POIs.")
pois_omf.head()
# Out:
# Loaded 102281 POIs.
#                                      id  \
# 0  f34e4f41-f8f6-45cf-9cd9-85cb47105c49
# 1  4c2abb7c-ab2c-488a-9149-23544432a0ec
# 2  52353f88-da75-4452-9ff8-1ff203c57add
# 3  c01c91ce-b198-475d-9686-ab61669e4cc7
# 4  aa2a5fc0-5ba3-439b-aa1d-78b6faadf706
#
#                                                name       top_category  \
# 0  Althof-Reitstall, Jausenstation, Ferienwohnungen    animal_boarding
# 1                                        Grundlacke      historic_site
# 2                               Weingut Judith Beck             winery
# 3                   Raiffeisenlandesbank Burgenland  financial_service
# 4                                  Gsellmann Wohnen      accommodation
#
#                        sub_category  longitude   latitude operating_status
# 0               equestrian_facility  16.892112  47.825252             open
# 1                          fountain  16.875002  47.829726             open
# 2                      liquor_store  16.908103  47.898219             open
# 3          business_banking_service  16.908008  47.898258             open
# 4  landmark_and_historical_building  16.905834  47.899528             open

# %%
# pois_fsq = parse_geometry(pois_fsq, crs='EPSG:3035')
# pois_omf = parse_geometry(pois_omf, crs='EPSG:3035')

# %% [markdown]
# ## 4. Aggregate to H3 Cells

# %%
resolution = 9
pois_fsq = pois_to_h3(pois_fsq, 'latitude', 'longitude', resolution, geometry=False)
pois_omf = pois_to_h3(pois_omf, 'latitude', 'longitude', resolution, geometry=False)
matrix_fsq = aggregate_by_h3(pois_fsq, f'h3_lvl{resolution}', 'top_category')
matrix_omf = aggregate_by_h3(pois_omf, f'h3_lvl{resolution}', 'top_category')
print(f"Comparison: {matrix_fsq.shape} x {matrix_omf.shape}")
# Out:
# Comparison: (12782, 10) x (10610, 362)

# %% [markdown]
# ## 5. Compute Complexity

# %%
profile = compute_complexity(
    pois_omf,
    unit_col=f"h3_lvl{resolution}",
    category_col="sub_category",
    methods=("juhasz", "hidalgo"),
)

# %%
profile.units.head()
# Out:
#                  n_amenities  n_categories  diversity_rca  complexity_juhasz  \
# h3_lvl9
# 891e02c021bffff            1             1              1           0.452996
# 891e02c0243ffff            4             4              4          -0.668766
# 891e02c0247ffff            1             1              1           0.238857
# 891e02c024bffff            5             4              4           0.264587
# 891e02c024fffff           15            14             14          -0.662652
#
#                  complexity_hidalgo
# h3_lvl9
# 891e02c021bffff            0.001906
# 891e02c0243ffff            0.001906
# 891e02c0247ffff            0.001906
# 891e02c024bffff            0.001906
# 891e02c024fffff            0.001906

# %%
profile.categories.head()
# Out:
#                                ubiquity_rca  complexity_juhasz  \
# sub_category
# abortion_clinic                           1          -0.163090
# abuse_and_addiction_treatment             6          -0.167083
# accommodation                           538           1.385954
# accountant                              147           2.833143
# acoustical_consultant                     1          -0.178656
#
#                                complexity_hidalgo
# sub_category
# abortion_clinic                         -0.010561
# abuse_and_addiction_treatment           -0.010561
# accommodation                           -0.010561
# accountant                              -0.010561
# acoustical_consultant                   -0.010561

# %% [markdown]
# ## 6. Visualize
# We can join the results back to geometries (H3 polygons) and plot.

# %%
results = profile.units
results['geometry'] = results.index.map(h3_to_polygon)
results = gpd.GeoDataFrame(results, crs="EPSG:4326").to_crs("EPSG:3035")
boundary = city_fua.to_crs("EPSG:3035").geometry.convex_hull.buffer(5000)

# winsorise the results
results['complexity_juhasz'] = results['complexity_juhasz'].clip(
    lower=results['complexity_juhasz'].quantile(0.01), 
    upper=results['complexity_juhasz'].quantile(0.99)
)

# clip to the FUA
results = results.clip(boundary)

fig, ax = plt.subplots(figsize=(10, 10))
boundary.plot(ax=ax, color='none', edgecolor='black', linewidth=5)
results.plot(column='complexity_juhasz', ax=ax, legend=True, cmap='viridis')

ax.set_axis_off()
ax.set_aspect('equal')

plt.title(f"Amenity Complexity in {target_city}", weight='bold' )
plt.show()

# %% [markdown]
# # 3. Buildings

# %%
bldg = buildings_from_overture(bbox=bbox, trim_cols=False, geometry_format="wkt")
bldg = clean_overture_buildings(bldg)

# %%
# convert to gdf
from shapely import wkt
bldg['geometry'] = bldg['geometry'].apply(wkt.loads)   
bldg = gpd.GeoDataFrame(bldg, geometry='geometry', crs='EPSG:4326')

# %%
prts = building_parts_from_overture(bbox=bbox, trim_cols=False, geometry_format="wkt")
prts = clean_overture_buildings(prts)

# %%
from shapely import wkt
prts['geometry'] = prts['geometry'].apply(wkt.loads)   
prts = gpd.GeoDataFrame(prts, geometry='geometry', crs='EPSG:4326')

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 6), subplot_kw={'aspect': 'equal'})

xlim = [16.4 - 0.1, 16.4 + 0.1]
ylim = [48.2 - 0.1, 48.2 + 0.1]

bldg.plot(ax=ax1, color='k')
ax1.set_xlim(xlim)
ax1.set_ylim(ylim)
ax1.set_axis_off()
ax1.set_title('Buildings', weight='bold')

prts.plot(ax=ax2, color='k')
ax2.set_xlim(xlim)
ax2.set_ylim(ylim)
ax2.set_axis_off()
ax2.set_title('Parts', weight='bold')

plt.tight_layout()
plt.show()
